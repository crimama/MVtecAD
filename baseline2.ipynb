# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://golmok.seoul.go.kr/stateArea.do')
print(res.content)

# %%
soup = BeautifulSoup(res.content,'html.parser')

# %%
soup.select('article div ')
# Out:
# [<div id="cnt">
#  <!-- [Dev] 페이지명 -->
#  <article class="wrap_inner" id="stateArea">
#  <h3 class="subtitle">지역분석</h3>
#  <select id="infoCategory" onchange="changeCondition()" style="display:none" title="정보분류 선택">
#  <option selected="" value="none">정보분류 선택</option>
#  <option value="store">점포수</option>
#  <option value="survival">신생기업 생존율</option>
#  <option value="survival2">연차별 생존율</option>
#  <option value="operatingPeriod">평균영업기간</option>
#  <option value="opening">개폐업수(률)</option>
#  <option value="population">인구수</option>
#  <option value="income">소득/가구수</option>
#  <option value="rent">임대시세</option>
#  </select>
#  <!-- 			<select title="기준 년월분기 선택" id="selectTerm" onchange="getTermData()" style="display:none"> -->
#  <!-- 				<option value="month" style="display: none;">월</option> -->
#  <!-- 				<option value="quarter" selected>분기</option> -->
#  <!-- 				<option value="year">년</option> -->
#  <!-- 			</select> -->
#  <div class="searchArea forPc">
# ...
